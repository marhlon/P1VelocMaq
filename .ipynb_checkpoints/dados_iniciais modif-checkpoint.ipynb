# %% [markdown]
# # Materiais extrusados - Técnicas de Machine Learning

# %% [markdown]
# ### Métodos:
#
# * Regressão Linear
# * Regressão Logistica
# * SVM
# * KNN (Classificação e Regressão)
# * RandomForest (Classificação e Regressão)
# * DecisionTree (Classificação e Regressão)
# * Redes Neurais (Classificação e Regressão)

# %%
# !python --version
# Out:
# Python 3.9.6

# %%
import tensorflow as tf
print("Num GPUs Available", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available 0

# %%
# Importando as bibliotecas (pandas, numpy, matplotlib e seaborn, StandardScaler e train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, precision_score, classification_report ,confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

import warnings
warnings.filterwarnings("ignore")

# %%
#importando o arquivo de dados
base_extrusao = 'dados_analise 2.xlsx'
df = pd.read_excel(base_extrusao)

# %%
#Avaliando e verificando os dados
df.head()
# Out:
#    N° CAMADAS        FILME   µm  Item de Linha     Cor     Máquina  \
# 0           7  Material 01  180              1  Cor 01  Máquina 01
# 1           7  Material 01  200              1  Cor 01  Máquina 01
# 2           7  Material 01  220              1  Cor 01  Máquina 01
# 3           7  Material 01  250              1  Cor 01  Máquina 01
# 4           7  Material 01  100              1  Cor 01  Máquina 01
#
#   Centro de Trabalho  VELOCIDADE (Kg/Hora)  Setup (hora)  Perda (%)
# 0          Centro 01                     3         0.362       3.25
# 1          Centro 01                     3         0.362       3.25
# 2          Centro 01                     3         0.362       3.25
# 3          Centro 01                     3         0.362       3.25
# 4          Centro 01                     3         0.362       3.25

# %% [markdown]
# # Análise de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   N° CAMADAS            756 non-null    int64
#  1   FILME                 756 non-null    object
#  2   µm                    756 non-null    int64
#  3   Item de Linha         756 non-null    int64
#  4   Cor                   756 non-null    object
#  5   Máquina               756 non-null    object
#  6   Centro de Trabalho    756 non-null    object
#  7   VELOCIDADE (Kg/Hora)  756 non-null    int64
#  8   Setup (hora)          756 non-null    float64
#  9   Perda (%)             756 non-null    float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 59.2+ KB

# %%
df.describe()
# Out:
#        N° CAMADAS          µm  Item de Linha  VELOCIDADE (Kg/Hora)  \
# count  756.000000  756.000000     756.000000            756.000000
# mean     5.671958   97.026455       0.529101              1.980159
# std      2.488289   50.381636       0.499483              0.744696
# min      3.000000   14.000000       0.000000              1.000000
# 25%      3.000000   65.000000       0.000000              1.000000
# 50%      7.000000   87.000000       1.000000              2.000000
# 75%      7.000000  119.250000       1.000000              3.000000
# max      9.000000  308.000000       1.000000              3.000000
#
#        Setup (hora)   Perda (%)
# count    756.000000  756.000000
# mean       0.249061    3.813439
# std        0.055356    2.564310
# min        0.197000    2.690000
# 25%        0.197000    2.780000
# 50%        0.251000    2.780000
# 75%        0.292000    3.250000
# max        0.362000   13.080000

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(12,6))
corr = df.corr()
sns.heatmap(corr, cmap="YlGnBu", annot=True, yticklabels=["01", "02", "03", "04", "05", "06", "07"], xticklabels=["01", "02", "03", "04", "05", "06", "07"])
plt.savefig('Imagens\Heatmap das informações.png', format='png')
#

# %%
maquina = df['Máquina'].value_counts()
legenda = ['Máquina 1', 'Máquina 2', 'Máquina 3', 'Máquina 4']

#Criação do Gráfico
plt.pie(maquina, labels=legenda, autopct='%1.1f%%', shadow=True, startangle=90)

#Adiciona Legenda
plt.legend(legenda, bbox_to_anchor=(1.3, 1.3), loc='upper right')

#Centraliza o gráfico
plt.axis('equal')

#Ajusta o espaçamento para evitar o recorte do rótulo
plt.tight_layout()
plt.legend().remove()
plt.savefig('Imagens\Percentual de Filmes por Máquina.png', format='png')
plt.show()

# %%
camada = df['N° CAMADAS'].value_counts()
legenda = ['3 Camadas', '7 Camadas', '9 Camadas']

#Criação do Gráfico
plt.pie(camada, labels=legenda, autopct='%1.1f%%', shadow=True, startangle=90)

#Adiciona Legenda
plt.legend(legenda, bbox_to_anchor=(1.3, 1.3), loc='upper right')

#Centraliza o gráfico
plt.axis('equal')

#Ajusta o espaçamento para evitar o recorte do rótulo
plt.tight_layout()
plt.legend().remove()
plt.savefig('Imagens\Percentual de Filmes por Camadas.png', format='png')
plt.show()

# %%
material = df['FILME'].value_counts()
legenda = ['Material 1', 'Material 2', 'Material 3', 'Material 4', 'Material 5', 'Material 6']

#Criação do Gráfico
plt.pie(material, labels=legenda, autopct='%1.1f%%', shadow=True, startangle=90)

#Adiciona Legenda
plt.legend(legenda, bbox_to_anchor=(1.3, 1.3), loc='upper right')

#Centraliza o gráfico
plt.axis('equal')

#Ajusta o espaçamento para evitar o recorte do rótulo
plt.tight_layout()
plt.legend().remove()
plt.savefig('Imagens\Percentual de Filmes por Material.png', format='png')
plt.show()

# %%
velocidade = df['VELOCIDADE (Kg/Hora)'].value_counts()
sns.distplot(velocidade)
plt.savefig("Imagens\Contagem de Velocidade.png")

# %%
setup = df['Setup (hora)'].value_counts()
sns.distplot(setup)
plt.savefig("Imagens\Contagem de Setup.png")

# %%
from scipy import stats
def quantile_plot(x, **kwargs):
    quantiles, xr = stats.probplot(x, fit=False)
    plt.scatter(xr, quantiles, **kwargs)

g = sns.FacetGrid(df, col="Máquina", height=4)
g.map(quantile_plot, "VELOCIDADE (Kg/Hora)")
plt.savefig("Imagens\Distribuição de velocidades.png")

# %%
g = sns.boxplot(x="Máquina", y="VELOCIDADE (Kg/Hora)", data=df, palette="deep")
plt.savefig("Imagens\Distribuição de velocidades.png")

# %%
from scipy import stats
def quantile_plot(x, **kwargs):
    quantiles, xr = stats.probplot(x, fit=False)
    plt.scatter(xr, quantiles, **kwargs)

g = sns.FacetGrid(df, col="Máquina", height=4)
g.map(quantile_plot, "Setup (hora)")
plt.savefig("Imagens\Distribuição de setups.png")

# %%
g = sns.boxplot(x="Máquina", y="Setup (hora)", data=df, palette="deep")
plt.savefig("Imagens\Distribuição de setups.png")

# %%
def qqplot(x, y, **kwargs):
    _, xr = stats.probplot(x, fit=False)
    _, yr = stats.probplot(y, fit=False)
    plt.scatter(xr, yr, **kwargs)
    
g = sns.FacetGrid(df, hue="VELOCIDADE (Kg/Hora)", col="Máquina", height=4)
g.map(qqplot, "VELOCIDADE (Kg/Hora)", "Setup (hora)")
g.add_legend()
plt.savefig("Imagens\Correção entre Máquina-velocidade-setup.png")

# %%
def qqplot(x, y, **kwargs):
    _, xr = stats.probplot(x, fit=False)
    _, yr = stats.probplot(y, fit=False)
    plt.scatter(xr, yr, **kwargs)
    
g = sns.FacetGrid(df, hue="VELOCIDADE (Kg/Hora)", col="Máquina", height=4)
g.map(qqplot, "VELOCIDADE (Kg/Hora)", "µm")
#g.add_legend()
plt.savefig("Imagens\Correção entre Máquina-velocidade-espessura.png")

# %%
plt.figure(figsize=(12,6))

sns.set_theme(style="whitegrid", palette="muted")

# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=df, x="Máquina", y="µm", hue="FILME")
ax.set(ylabel="Espessura")
ax.set(xlabel="Máquina")

plt.legend()
plt.savefig("Imagens\Correlação entre Máquina-espessura-Material.png")

# %%
g = sns.boxplot(x="Máquina", y="µm", hue="FILME", data=df, palette="deep")
g = sns.swarmplot(x="Máquina", y="µm", data=df, palette="deep", color=".25")
#plt.savefig("Imagens\Distribuição de setups.png")

# %%
plt.figure(figsize=(12,6))

sns.set_theme(style="whitegrid", palette="muted")

# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=df, x="Setup (hora)", y="VELOCIDADE (Kg/Hora)", hue="FILME")
ax.set(ylabel="Velocidade")
ax.set(xlabel="Setup")

plt.legend()
plt.savefig("Correlação entre Velocidade-setup-Material.png")
plt.show()

# %% [markdown]
# # Mineração de dados

# %%
# identificação da menor taxa de erro
def buscarMenor(lst):
    i = float("inf")
    for nr in lst:
        if nr < i:
            i = nr
            c = lst.index(nr)
    return c + 1

# %%
def min(matriz):
    menor = matriz[0][0]
    for r in range(len(matriz)):
        nums = matriz[r]
        for n in nums:
            menor = n if menor > n else menor
            c = matriz.index(n)
            d = r
    return c, d

# %%
# Divisão dos dados
X = df.iloc[: , [0,1,2,3,4,5,6,8,9]].values
y = df['VELOCIDADE (Kg/Hora)']

# %%
X[1]
# Out:
# array([7, 'Material 01', 200, 1, 'Cor 01', 'Máquina 01', 'Centro 01',
#        0.362, 3.25], dtype=object)

# %%
labelencoder = LabelEncoder()
X[:, 1] = labelencoder.fit_transform(X[:, 1])
X[:, 4] = labelencoder.fit_transform(X[:, 4])
X[:, 5] = labelencoder.fit_transform(X[:, 5])
X[:, 6] = labelencoder.fit_transform(X[:, 6])

# %%
onehotencoder = ColumnTransformer(transformers=[("OneHot", OneHotEncoder(), [1,4,6,7])],remainder='passthrough')
X = onehotencoder.fit_transform(X)

# %%
#y = pd.DataFrame(y)
normalizador = MinMaxScaler(feature_range= (0,1))
X = normalizador.fit_transform(X)
#y = normalizador.fit_transform(y)
#y = pd.DataFrame(y)

# %%
X = pd.DataFrame(X)

# %%
#Algoritmo de repetição para análise de métodos de classificação
def testeMaquina(metEsc):
    i = 0
    classi_analise = []
    #confu_analise_test = []
    #confu_analise_train = []
    # Laço de 10 repetições para retirar média dos testes
    for i in range (0,100):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=i)
        #scaler = StandardScaler()
        #X_train_pad = scaler.fit_transform(X_train)
        #X_test_pad = scaler.fit_transform(X_test)
        logmodel = metEsc
        logmodel.fit(X_train, y_train)
        #predição
        predictions = logmodel.predict(X_test)
        predictions2 = logmodel.predict(X_train)
        #imprimindo classificação
        classi_analise.append(accuracy_score(y_test,predictions))
        classi_analise.append(accuracy_score(y_train,predictions2))
        classi_analise.append(precision_score(y_test,predictions, average='weighted'))
        classi_analise.append(precision_score(y_train,predictions2, average='weighted'))
        classi_analise.append(f1_score(y_test,predictions, average='weighted'))
        classi_analise.append(f1_score(y_train,predictions2, average='weighted'))
        #confu_analise_test.append(confusion_matrix(y_test,predictions))
        #confu_analise_train.append(confusion_matrix(y_train,predictions2))
        
    i =+ 1
    
    # Reformulando os dados e remodelando
    classi_analise = pd.DataFrame(data=np.reshape(classi_analise, (100, 6)), index=None,
                                  columns=['Acuracia_Teste', 'Acuracia_Treino', 'Precisao_Teste',
                                           'Precisao_Treino','F1_Teste', 'F1_Treino'])
    #confu_analise_test = pd.DataFrame(data=np.reshape(confu_analise_test, (100, 1)), index=None, columns=None)
    #confu_analise_train = pd.DataFrame(data=np.reshape(confu_analise_train, (100, 256)), index=None, columns=None)
    
    # Exportando dados para análise
    classi_analise.to_csv('Relatorio2/Classificacao/classification_report_{}.csv'.format(str(metEsc)), index=False)
    #confu_analise_test.to_csv('Relatorio/PCA/confusion_matrix_test_{}.csv'.format(str(metEsc)), index=False)
    #confu_analise_train.to_csv('Relatorio/PCA/confusion_matrix_train{}.csv'.format(str(metEsc)), index=False)
    
    # reset dos valores
    classi_analise = []
    #confu_analise_test = []
    #confu_analise_train = []

# %% [markdown]
# ## Técnicas de Classificação

# %% [markdown]
# Naive Bayes

# %%
#Importando o método de RL
from sklearn.naive_bayes import BernoulliNB

# %%
metEsc = BernoulliNB()
testeMaquina(metEsc)

# %% [markdown]
# Regressão Logistica

# %%
#Importando o método de RL
from sklearn.linear_model import LogisticRegression

# %%
metEsc = LogisticRegression()
testeMaquina(metEsc)

# %% [markdown]
# KNN

# %%
#Importando o método KNN
from sklearn.neighbors import KNeighborsClassifier

# %%
#criação de conjunto vazio
error_rate = []

#Tamanho do laço for para testes
k = 30
t = 100

for j in range(1, t+1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=j)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    #criação de laço for, para definir melhor número de vizinhos
    for i in range(1,k+1):
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(X_train, y_train)
        pred = knn.predict(X_test)
        error_rate.append(np.mean(pred != y_test))

valor_menor = buscarMenor(error_rate)
print("random_state: ", int((valor_menor-1)/k), '\n', 'n_neighbors: ', ((valor_menor-1)%k)+1)
menor = ((valor_menor-1)%k)+1
# Out:
# random_state:  5
#  n_neighbors:  1

# %%
#sem definição de número de visinhos
metEsc = KNeighborsClassifier()
testeMaquina(metEsc)

i = 0
classi_analise = []
#confu_analise_test = []
#confu_analise_train = []
# Laço de 10 repetições para retirar média dos testes
for i in range (0,100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=5)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    knn = KNeighborsClassifier(n_neighbors=1)
    knn.fit(X_train, y_train)
    #predição
    predictions = knn.predict(X_test)
    predictions2 = knn.predict(X_train)
    #imprimindo classificação
    classi_analise.append(accuracy_score(y_test,predictions))
    classi_analise.append(accuracy_score(y_train,predictions2))
    classi_analise.append(precision_score(y_test,predictions, average='weighted'))
    classi_analise.append(precision_score(y_train,predictions2, average='weighted'))
    classi_analise.append(f1_score(y_test,predictions, average='weighted'))
    classi_analise.append(f1_score(y_train,predictions2, average='weighted'))
        
i =+ 1
    
# Reformulando os dados e remodelando
classi_analise = pd.DataFrame(data=np.reshape(classi_analise, (100, 6)), index=None,
                                  columns=['Acuracia_Teste', 'Acuracia_Treino', 'Precisao_Teste',
                                           'Precisao_Treino','F1_Teste', 'F1_Treino'])
# Exportando dados para análise
classi_analise.to_csv('Relatorio2/Classificacao/classification_report_KNeighborsClassifier(n_neighbors=1).csv'.format(str(metEsc)), index=False)
    
# reset dos valores
classi_analise = []

# %% [markdown]
# SVM

# %%
#importando biblioteca
from sklearn.svm import SVC

# %%
metEsc = SVC()
testeMaquina(metEsc)

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
#scaler = StandardScaler()
#X_train_pad = scaler.fit_transform(X_train)
#X_test_pad = scaler.fit_transform(X_test)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.670 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.566 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.651 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.642 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.648 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.443 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.438 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.443 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.438 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.443 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.438 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.726 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.726 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.651 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.604 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.686 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.443 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.438 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.443 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.438 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.736 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.724 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.736 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.743 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.604 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.686 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.434 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.443 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.438 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.726 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.821 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.762 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.736 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.689 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.752 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.689 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.755 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.670 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.676 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.604 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.679 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.623 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.686 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.792 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.726 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.771 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.783 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.774 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.752 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.698 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.743 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.651 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.695 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.708 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.660 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.695 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid.best_params_
c = grid.best_params_['C']
gamma = grid.best_params_['gamma']
kernel = grid.best_params_['kernel']

# %%
grid.best_estimator_
# Out:
# SVC(C=1000, gamma=1)

# %%
metEsc = SVC(C = c, gamma = gamma, kernel = kernel)
testeMaquina(metEsc)

# %% [markdown]
# Árvore de Classificação

# %%
#importando biblioteca
from sklearn.tree import DecisionTreeClassifier

# %%
#criação de conjunto vazio
error_rate = []

#Tamanho do laço for para testes
k = 30
t = 100

for j in range(1, t+1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=j)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    #criação de laço for, para definir melhor número de vizinhos
    for i in range(1,k+1):
        dectree = DecisionTreeClassifier(max_depth=i)
        dectree.fit(X_train, y_train)
        pred = dectree.predict(X_test)
        error_rate.append(np.mean(pred != y_test))

valor_menor = buscarMenor(error_rate)
print("random_state: ", int((valor_menor-1)/k), '\n', 'n_neighbors: ', ((valor_menor-1)%k)+1)
menor = ((valor_menor-1)%k)+1
# Out:
# random_state:  9
#  n_neighbors:  11

# %%
#sem definição de profunidade dos nós
metEsc = DecisionTreeClassifier()
testeMaquina(metEsc)

i = 0
classi_analise = []
# Laço de 10 repetições para retirar média dos testes
for i in range (0,100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=9)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    treeClas = DecisionTreeClassifier(max_depth=11)
    treeClas.fit(X_train, y_train)
    #predição
    predictions = treeClas.predict(X_test)
    predictions2 = treeClas.predict(X_train)
    #imprimindo classificação
    classi_analise.append(accuracy_score(y_test,predictions))
    classi_analise.append(accuracy_score(y_train,predictions2))
    classi_analise.append(precision_score(y_test,predictions, average='weighted'))
    classi_analise.append(precision_score(y_train,predictions2, average='weighted'))
    classi_analise.append(f1_score(y_test,predictions, average='weighted'))
    classi_analise.append(f1_score(y_train,predictions2, average='weighted'))
        
i =+ 1
    
# Reformulando os dados e remodelando
classi_analise = pd.DataFrame(data=np.reshape(classi_analise, (100, 6)), index=None,
                                  columns=['Acuracia_Teste', 'Acuracia_Treino', 'Precisao_Teste',
                                           'Precisao_Treino','F1_Teste', 'F1_Treino'])
# Exportando dados para análise
classi_analise.to_csv('Relatorio2/Classificacao/classification_report_DecisionTreeClassifier(max_depth=11).csv'.format(str(metEsc)), index=False)
    
# reset dos valores
classi_analise = []

# %% [markdown]
# Random Forest

# %%
#importando biblioteca
from sklearn.ensemble import RandomForestClassifier

# %%
#criação de conjunto vazio
error_rate = []

#Tamanho do laço for para testes
k = 30
t = 100

for j in range(1, t+1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=j)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    #criação de laço for, para definir melhor número de vizinhos
    for i in range(10,310,10):
        randfor = RandomForestClassifier(n_estimators=i)
        randfor.fit(X_train, y_train)
        pred = randfor.predict(X_test)
        error_rate.append(np.mean(pred != y_test))

valor_menor = buscarMenor(error_rate)
print("random_state: ", int((valor_menor-1)/k), '\n', 'n_neighbors: ', ((valor_menor-1)%k)+1)
menor = ((valor_menor-1)%k)+1
# Out:
# random_state:  7
#  n_neighbors:  5

# %%
#sem definição de profunidade dos nós
metEsc = RandomForestClassifier()
testeMaquina(metEsc)

i = 0
classi_analise = []
#confu_analise_test = []
#confu_analise_train = []
# Laço de 10 repetições para retirar média dos testes
for i in range (0,100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    randFore = RandomForestClassifier(n_estimators=50)
    randFore.fit(X_train, y_train)
    #predição
    predictions = randFore.predict(X_test)
    predictions2 = randFore.predict(X_train)
    #imprimindo classificação
    classi_analise.append(accuracy_score(y_test,predictions))
    classi_analise.append(accuracy_score(y_train,predictions2))
    classi_analise.append(precision_score(y_test,predictions, average='weighted'))
    classi_analise.append(precision_score(y_train,predictions2, average='weighted'))
    classi_analise.append(f1_score(y_test,predictions, average='weighted'))
    classi_analise.append(f1_score(y_train,predictions2, average='weighted'))
        
i =+ 1
    
# Reformulando os dados e remodelando
classi_analise = pd.DataFrame(data=np.reshape(classi_analise, (100, 6)), index=None,
                                  columns=['Acuracia_Teste', 'Acuracia_Treino', 'Precisao_Teste',
                                           'Precisao_Treino','F1_Teste', 'F1_Treino'])
# Exportando dados para análise
classi_analise.to_csv('Relatorio2/Classificacao/classification_report_RandomForestClassifier(n_estimators=50).csv'.format(str(metEsc)), index=False)
    
# reset dos valores
classi_analise = []

# %% [markdown]
# ANN

# %%
#importando biblioteca
from sklearn.neural_network import MLPClassifier

# %%
#criação de conjunto vazio
error_rate = []

#Tamanho do laço for para testes
k = 30
t = 100

for j in range(1, t+1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=j)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    #criação de laço for, para definir melhor número de vizinhos
    for i in range(2000,32000,1000):
        ann = MLPClassifier(max_iter=i)
        ann.fit(X_train, y_train)
        pred = ann.predict(X_test)
        error_rate.append(np.mean(pred != y_test))

valor_menor = buscarMenor(error_rate)
print("random_state: ", int((valor_menor-1)/k), '\n', 'n_neighbors: ', ((valor_menor-1)%k)+1)
menor = ((valor_menor-1)%k)+1
# Out:
# random_state:  16
#  n_neighbors:  28

# %%
#sem definição de profunidade dos nós
metEsc = MLPClassifier()
testeMaquina(metEsc)

i = 0
classi_analise = []
#confu_analise_test = []
#confu_analise_train = []
# Laço de 10 repetições para retirar média dos testes
for i in range (0,100):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=16)
    #scaler = StandardScaler()
    #X_train_pad = scaler.fit_transform(X_train)
    #X_test_pad = scaler.fit_transform(X_test)
    ann = MLPClassifier(max_iter=29000)
    ann.fit(X_train, y_train)
    #predição
    predictions = ann.predict(X_test)
    predictions2 = ann.predict(X_train)
    #imprimindo classificação
    classi_analise.append(accuracy_score(y_test,predictions))
    classi_analise.append(accuracy_score(y_train,predictions2))
    classi_analise.append(precision_score(y_test,predictions, average='weighted'))
    classi_analise.append(precision_score(y_train,predictions2, average='weighted'))
    classi_analise.append(f1_score(y_test,predictions, average='weighted'))
    classi_analise.append(f1_score(y_train,predictions2, average='weighted'))
        
i =+ 1
    
# Reformulando os dados e remodelando
classi_analise = pd.DataFrame(data=np.reshape(classi_analise, (100, 6)), index=None,
                                  columns=['Acuracia_Teste', 'Acuracia_Treino', 'Precisao_Teste',
                                           'Precisao_Treino','F1_Teste', 'F1_Treino'])
# Exportando dados para análise
classi_analise.to_csv('Relatorio2/Classificacao/classification_report_MLPClassifier(max_iter=29000).csv'.format(str(metEsc)), index=False)
    
# reset dos valores
classi_analise = []
