# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Métodos de Classificação

# %%
metodos = ['BernoulliNB()', 'LogisticRegression()', 'KNeighborsClassifier()', 'KNeighborsClassifier(n_neighbors=1)',
           'SVC()', 'SVC(C=1000, gamma=0.1)', 'DecisionTreeClassifier()', 'DecisionTreeClassifier(max_depth=11)',
           'RandomForestClassifier()', 'RandomForestClassifier(n_estimators=200)', 'MLPClassifier()', 'MLPClassifier(max_iter=16000)']

avaliacoes = ['Acuracia_Teste', 'Acuracia_Treino', 'Precisao_Teste', 'Precisao_Treino','F1_Teste', 'F1_Treino']

db0 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[0])))
db1 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[1])))
db2 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[2])))
db3 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[3])))
db4 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[4])))
db5 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[5])))
db6 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[6])))
db7 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[7])))
db8 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[8])))
db9 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[9])))
db10 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[10])))
db11 = pd.read_csv('Relatorio/Classificacao/classification_report_{}.csv'.format(str(metodos[11])))

# %%
db0.head()
# Out:
#    Acuracia_Teste  Acuracia_Treino  Precisao_Teste  Precisao_Treino  F1_Teste  \
# 0        0.466960         0.491493        0.430016         0.480674  0.415353
# 1        0.431718         0.491493        0.312228         0.567236  0.349710
# 2        0.436123         0.461248        0.599828         0.421701  0.402796
# 3        0.462555         0.497164        0.393384         0.588633  0.395676
# 4        0.480176         0.487713        0.405745         0.607101  0.413208
#
#    F1_Treino
# 0   0.421388
# 1   0.422002
# 2   0.413125
# 3   0.438671
# 4   0.432360

# %%
metleg = ['NB', 'RegLog', 'KNN', 'KNN(BP*)', 'SVC', 'SVC(BP*)', 'ArvClas', 'ArvClas(BP*)', 'RanFor', 'RanFor(BP*)', 'ANN', 'ANN(BP*)']

# %%
legenda = ['NB', 'RegLog', 'KNN', 'KNN(BP*)', 'SVC', 'SVC(BP*)', 'ArvClas', 'ArvClas(BP*)', 'RanFor', 'RanFor(BP*)', 'ANN', 'Classe']

# %%
mediasCalc = []
mediasTest = []
mediasTrain = []
AcuraciaTe = []
AcuraciaTr = []
PrecisaoTe = []
PrecisaoTr = []
F1Te = []
F1Tr = []

# %%
def calcMedia(database):
    for i in range(0,len(avaliacoes)):
        mediasCalc.append(database.mean()[i])
        
def mediaMatrizTest(database):
    for i in range(0,4):
        mediasTest.append(database.mean()[i])

def mediaMatrizTrain(database):
    for i in range(0,4):
        mediasTrain.append(database.mean()[i])
        
def incluirDados(database):
    for i in range(0, len(database['Acuracia_Teste'])):
        AcuraciaTe.append(database['Acuracia_Teste'][i])
    for i in range(0, len(database['Acuracia_Treino'])):
        AcuraciaTr.append(database['Acuracia_Treino'][i])
    for i in range(0, len(database['Precisao_Teste'])):
        PrecisaoTe.append(database['Precisao_Teste'][i])
    for i in range(0, len(database['Precisao_Treino'])):
        PrecisaoTr.append(database['Precisao_Treino'][i])
    for i in range(0, len(database['F1_Teste'])):
        F1Te.append(database['F1_Teste'][i])
    for i in range(0, len(database['F1_Treino'])):
        F1Tr.append(database['F1_Treino'][i])
        
def autolabel(Grupos):
    for i in Grupos:
        h = i.get_height()
        ax.annotate('{0:.0f}%'.format(h*100),
            xy = (i.get_x()+i.get_width()/2,h),
            xytext = (0,3),
            textcoords = 'offset points',
            ha = 'center')

# %%
incluirDados(db0)
incluirDados(db1)
incluirDados(db2)
incluirDados(db3)
incluirDados(db4)
incluirDados(db5)
incluirDados(db6)
incluirDados(db7)
incluirDados(db8)
incluirDados(db9)
incluirDados(db10)
incluirDados(db11)

# %%
calcMedia(db0)
calcMedia(db1)
calcMedia(db2)
calcMedia(db3)
calcMedia(db4)
calcMedia(db5)
calcMedia(db6)
calcMedia(db7)
calcMedia(db8)
calcMedia(db9)
calcMedia(db10)
calcMedia(db11)

# %%
mediasCalc = pd.DataFrame(data=np.reshape(mediasCalc, (12,6)), index=metodos, columns=avaliacoes)
mediasCalc
# Out:
#                                           Acuracia_Teste  Acuracia_Treino  \
# BernoulliNB()                                   0.458326         0.489546
# LogisticRegression()                            0.528458         0.570246
# KNeighborsClassifier()                          0.571454         0.710378
# KNeighborsClassifier(n_neighbors=1)             0.665198         0.879017
# SVC()                                           0.515991         0.566597
# SVC(C=1000, gamma=0.1)                          0.604934         0.686635
# DecisionTreeClassifier()                        0.654361         0.902817
# DecisionTreeClassifier(max_depth=11)            0.678943         0.856333
# RandomForestClassifier()                        0.648855         0.902779
# RandomForestClassifier(n_estimators=200)        0.660881         0.907372
# MLPClassifier()                                 0.565110         0.621474
# MLPClassifier(max_iter=16000)                   0.582247         0.698526
#
# ...

# %%
AcuraciaTe = pd.DataFrame(data=np.reshape(AcuraciaTe, (12,100)))
AcuraciaTe = AcuraciaTe.T
AcuraciaTe.columns = metleg
AcuraciaTr = pd.DataFrame(data=np.reshape(AcuraciaTr, (12,100)))
AcuraciaTr = AcuraciaTr.T
AcuraciaTr.columns = metleg

# %%
AcuraciaTe
# Out:
#           NB    RegLog       KNN  KNN(BP*)       SVC  SVC(BP*)   ArvClas  \
# 0   0.466960  0.519824  0.577093  0.665198  0.537445  0.629956  0.656388
# 1   0.431718  0.515419  0.621145  0.665198  0.511013  0.629956  0.669604
# 2   0.436123  0.550661  0.616740  0.665198  0.524229  0.603524  0.665198
# 3   0.462555  0.546256  0.577093  0.665198  0.519824  0.581498  0.669604
# 4   0.480176  0.533040  0.533040  0.665198  0.550661  0.616740  0.678414
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.515419  0.563877  0.599119  0.665198  0.572687  0.660793  0.691630
# 96  0.475771  0.519824  0.572687  0.665198  0.480176  0.563877  0.700441
# 97  0.475771  0.493392  0.568282  0.665198  0.484581  0.559471  0.629956
# 98  0.453744  0.511013  0.541850  0.665198  0.488987  0.568282  0.621145
# 99  0.414097  0.484581  0.559471  0.665198  0.533040  0.616740  0.643172
#
#     ArvClas(BP*)    RanFor  RanFor(BP*)       ANN  ANN(BP*)
# ...

# %%
PrecisaoTe = pd.DataFrame(data=np.reshape(PrecisaoTe, (12,100)))
PrecisaoTe = PrecisaoTe.T
PrecisaoTe.columns = metleg
PrecisaoTr = pd.DataFrame(data=np.reshape(PrecisaoTr, (12,100)))
PrecisaoTr = PrecisaoTr.T
PrecisaoTr.columns = metleg

# %%
F1Te = pd.DataFrame(data=np.reshape(F1Te, (12,100)))
F1Te = F1Te.T
F1Te.columns = metleg
F1Tr = pd.DataFrame(data=np.reshape(F1Tr, (12,100)))
F1Tr = F1Tr.T
F1Tr.columns = metleg

# %%
PrecisaoTe
# Out:
#           NB    RegLog       KNN  KNN(BP*)       SVC  SVC(BP*)   ArvClas  \
# 0   0.430016  0.546837  0.545188  0.673922  0.534522  0.601657  0.671159
# 1   0.312228  0.439647  0.580143  0.673922  0.451685  0.612848  0.690772
# 2   0.599828  0.532497  0.627508  0.673922  0.507990  0.585563  0.683962
# 3   0.393384  0.535683  0.582538  0.673922  0.565745  0.570442  0.700228
# 4   0.405745  0.487146  0.521428  0.673922  0.583035  0.584016  0.686978
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.448265  0.543466  0.584857  0.673922  0.586384  0.657143  0.697935
# 96  0.550022  0.468477  0.570321  0.673922  0.490208  0.539994  0.717341
# 97  0.470060  0.502951  0.561855  0.673922  0.472163  0.530065  0.644462
# 98  0.380864  0.504903  0.572298  0.673922  0.462885  0.566034  0.639827
# 99  0.399616  0.527965  0.562491  0.673922  0.581824  0.604213  0.676027
#
#     ArvClas(BP*)    RanFor  RanFor(BP*)       ANN  ANN(BP*)
# ...

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 7))

bpl = plt.boxplot(AcuraciaTe, positions=np.array(range(len(AcuraciaTe.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(AcuraciaTr, positions=np.array(range(len(AcuraciaTr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Acurácia")
plt.xlabel("Método")
plt.ylabel("Percentual")

plt.savefig('Imagens\Avaliacao\BPAcuracia.jpeg')

# %%
width=0.9
x = np.array(range(len(AcuraciaTe.T)))

fig, ax = plt.subplots(figsize=(12,6))

bpl = ax.bar((x*2)-width/2, AcuraciaTe.mean(), width, label="Teste", color='#D7191C')
bpr = ax.bar((x*2)+width/2, AcuraciaTr.mean(), width, label="Treino", color='#2C7BB6')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Acurácia")
plt.xlabel("Método")
plt.ylabel("Percentual")

autolabel(bpl)
autolabel(bpr)

plt.savefig('Imagens\Avaliacao\Acuracia - Gráfico Barras.jpeg')

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 7))

bpl = plt.boxplot(PrecisaoTe, positions=np.array(range(len(PrecisaoTe.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(PrecisaoTr, positions=np.array(range(len(PrecisaoTr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Precisão")
plt.xlabel("Método")
plt.ylabel("Percentual")

plt.savefig('Imagens\Avaliacao\BPPrecisao.jpeg')

# %%
width=0.9
x = np.array(range(len(AcuraciaTe.T)))

fig, ax = plt.subplots(figsize=(12,6))

bpl = ax.bar((x*2)-width/2, PrecisaoTe.mean(), width, label="Teste", color='#D7191C')
bpr = ax.bar((x*2)+width/2, PrecisaoTr.mean(), width, label="Treino", color='#2C7BB6')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Precisão")
plt.xlabel("Método")
plt.ylabel("Percentual")

autolabel(bpl)
autolabel(bpr)

plt.savefig('Imagens\Avaliacao\Precisao - Gráfico Barras.jpeg')

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 7))

bpl = plt.boxplot(F1Te, positions=np.array(range(len(F1Te.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(F1Tr, positions=np.array(range(len(F1Tr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metleg) * 2, 2), metleg)
plt.xlim(-2, len(metleg)*2)
plt.title("Precisão")
plt.xlabel("Método")
plt.ylabel("Percentual")

plt.savefig('Imagens\Avaliacao\PF1.jpeg')

# %%
fig = plt.figure(figsize =(12, 7))
ax = fig.add_subplot()
plt.boxplot(db10)

plt.title("BoxPlot Testes")
plt.xlabel("Teste")
plt.ylabel("Percentual")
#ax.set_xticklabels(metleg)
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot()
plt.boxplot(AcuraciaTe)

plt.title("BoxPlot Testes")
#plt.xlabel("Teste")
#plt.ylabel("Percentual")
#ax.set_xticklabels(avaliacoes)
plt.show()

# %%
plt.figure(figsize=(12,8))

barWidth = 0.15

r1 = np.arange(len(mediasCalc.index))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

plt.bar(r1, mediasCalc['Acuracia_Teste'], color="#A637F0", width=barWidth, label="Acurácia Teste")
plt.bar(r2, mediasCalc['Acuracia_Treino'], color="#5A19FA", width=barWidth, label="Acurácia Treino")
plt.bar(r3, mediasCalc['Precisao_Teste'], color="#1B22E0", width=barWidth, label="Precisão Teste")
plt.bar(r4, mediasCalc['Precisao_Treino'], color="#1160F7", width=barWidth, label="Precisão Treino")
plt.bar(r5, mediasCalc['F1_Teste'], color="#119FED", width=barWidth, label="F1 Teste")
plt.bar(r6, mediasCalc['F1_Treino'], color="#14CEF0", width=barWidth, label="F1 Treino")

plt.xlabel('Métodos')
plt.xticks([r + barWidth for r in range(len(mediasCalc.index))], metleg)
plt.ylabel('Percentual')
plt.title('Avaliação dos Scores')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(18,6))

barWidth = 0.15

r1 = np.arange(len(db1.index))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]

plt.bar(r1, db1['Acuracia_Teste'], color="#A637F0", width=barWidth, label="Acurácia Teste")
plt.bar(r2, db1['Acuracia_Treino'], color="#5A19FA", width=barWidth, label="Acurácia Treino")
plt.bar(r3, db1['Precisao_Teste'], color="#1B22E0", width=barWidth, label="Precisão Teste")
plt.bar(r4, db1['Precisao_Treino'], color="#1160F7", width=barWidth, label="Precisão Treino")
plt.bar(r5, db1['F1_Teste'], color="#119FED", width=barWidth, label="F1 Teste")
plt.bar(r6, db1['F1_Treino'], color="#14CEF0", width=barWidth, label="F1 Treino")

plt.xlabel('Métodos')
plt.xticks(range(0,100))
plt.ylabel('Percentual')
plt.title('Avaliação dos Scores')

plt.legend()
plt.show()

# %%
db10.mean()
# Out:
# Acuracia_Teste     0.565110
# Acuracia_Treino    0.621474
# Precisao_Teste     0.544879
# Precisao_Treino    0.599729
# F1_Teste           0.531702
# F1_Treino          0.591519
# dtype: float64

# %%
db10.min()
# Out:
# Acuracia_Teste     0.493392
# Acuracia_Treino    0.584121
# Precisao_Teste     0.440916
# Precisao_Treino    0.556058
# F1_Teste           0.444915
# F1_Treino          0.545406
# dtype: float64

# %%
db10.max()
# Out:
# Acuracia_Teste     0.625551
# Acuracia_Treino    0.652174
# Precisao_Teste     0.620899
# Precisao_Treino    0.634337
# F1_Teste           0.600209
# F1_Treino          0.625369
# dtype: float64

# %% [markdown]
# ## Regressão

# %%
metodos = ['SVR()', 'SVR(C=100, gamma=0.1)', 'KNeighborsRegressor()', 'KNeighborsRegressor(n_neighbors=1)',
           'DecisionTreeRegressor()', 'DecisionTreeRegressor(max_depth=21)', 'RandomForestRegressor()',
           'RandomForestRegressor(n_estimators=10)', 'MLPRegressor(max_iter=2000)']

avaliacoes = ['Score', 'MAE_Teste', 'MAE_Treino', 'MSE_Teste', 'MSE_Treino', 'R2_Teste', 'R2_Treino', 'MAPE_Teste', 'MAPE_Treino']

db0 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[0])))
db1 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[1])))
db2 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[2])))
db3 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[3])))
db4 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[4])))
db5 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[5])))
db6 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[6])))
db7 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[7])))
db8 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodos[8])))

# %%
metlegreg = ['SVR', 'SVR(BP*)', 'KNN', 'KNN(BP*)', 'ArvReg', 'ArvReg(BP*)', 'RanFor', 'RanFor(BP*)', 'ANNR(BP*)']

# %%
mediasCalc = []
mediasTest = []
mediasTrain = []
ScoreReg = []
MAETe = []
MAETr = []
MSETe = []
MSETr = []
R2Te = []
R2Tr = []
MAPETe = []
MAPETr = []

# %%
def calcMedia(database):
    for i in range(0,len(avaliacoes)):
        mediasCalc.append(database.mean()[i])
        
def mediaMatrizTest(database):
    for i in range(0,4):
        mediasTest.append(database.mean()[i])

def mediaMatrizTrain(database):
    for i in range(0,4):
        mediasTrain.append(database.mean()[i])
        
def incluirDados(database):
    for i in range(0, len(database['Score'])):
        ScoreReg.append(database['Score'][i])
    for i in range(0, len(database['MAE_Teste'])):
        MAETe.append(database['MAE_Teste'][i])
    for i in range(0, len(database['MAE_Treino'])):
        MAETr.append(database['MAE_Treino'][i])
    for i in range(0, len(database['MSE_Teste'])):
        MSETe.append(database['MSE_Teste'][i])
    for i in range(0, len(database['MSE_Treino'])):
        MSETr.append(database['MSE_Treino'][i])
    for i in range(0, len(database['R2_Teste'])):
        R2Te.append(database['R2_Teste'][i])
    for i in range(0, len(database['R2_Treino'])):
        R2Tr.append(database['R2_Treino'][i])
    for i in range(0, len(database['MAPE_Teste'])):
        MAPETe.append(database['MAPE_Teste'][i])
    for i in range(0, len(database['MAPE_Treino'])):
        MAPETr.append(database['MAPE_Treino'][i])
        
def autolabel(Grupos):
    for i in Grupos:
        h = i.get_height()
        ax.annotate('{0:.0f}%'.format(h*100),
            xy = (i.get_x()+i.get_width()/2,h),
            xytext = (0,3),
            textcoords = 'offset points',
            ha = 'center')

# %%
incluirDados(db0)
incluirDados(db1)
incluirDados(db2)
incluirDados(db3)
incluirDados(db4)
incluirDados(db5)
incluirDados(db6)
incluirDados(db7)
incluirDados(db8)

# %%
calcMedia(db0)
calcMedia(db1)
calcMedia(db2)
calcMedia(db3)
calcMedia(db4)
calcMedia(db5)
calcMedia(db6)
calcMedia(db7)
calcMedia(db8)

# %%
mediasCalc = pd.DataFrame(data=np.reshape(mediasCalc, (9,9)), index=metodos, columns=avaliacoes)
mediasCalc
# Out:
#                                            Score  MAE_Teste  MAE_Treino  \
# SVR()                                   0.402235  39.538775   39.023235
# SVR(C=100, gamma=0.1)                   0.709472  22.446262   20.636008
# KNeighborsRegressor()                   0.786242  20.291542   15.869792
# KNeighborsRegressor(n_neighbors=1)      0.714325  17.444934    5.973535
# DecisionTreeRegressor()                 0.759465  17.275897    5.704997
# DecisionTreeRegressor(max_depth=21)     0.785339  15.746067    5.938203
# RandomForestRegressor()                 0.817818  17.143662    9.065668
# RandomForestRegressor(n_estimators=10)  0.776687  18.291624    8.198569
# MLPRegressor(max_iter=2000)             0.727807  25.474051   26.041723
#
#                                           MSE_Teste   MSE_Treino  R2_Teste  \
# SVR()                                   2430.264020  2399.315912  0.402235
# SVR(C=100, gamma=0.1)                   1178.038116  1080.836556  0.709472
# ...

# %%
plt.figure(figsize=(12,8))

barWidth = 0.15

r1 = np.arange(len(mediasCalc.index))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5]
r7 = [x + barWidth for x in r6]
r8 = [x + barWidth for x in r7]
r9 = [x + barWidth for x in r8]


plt.bar(r1, mediasCalc['Score'], color="#A637F0", width=barWidth, label="Score")
plt.bar(r2, mediasCalc['MAE_Teste'], color="#5A19FA", width=barWidth, label="MAE Teste")
plt.bar(r3, mediasCalc['MAE_Treino'], color="#1B22E0", width=barWidth, label="MAE Treino")
plt.bar(r4, mediasCalc['MSE_Teste'], color="#1160F7", width=barWidth, label="MSE Teste")
plt.bar(r5, mediasCalc['MSE_Treino'], color="#119FED", width=barWidth, label="MSE Treino")
plt.bar(r6, mediasCalc['R2_Teste'], color="#14CEF0", width=barWidth, label="R2 Teste")
plt.bar(r7, mediasCalc['R2_Treino'], color="#14CDA0", width=barWidth, label="R2 Treino")
plt.bar(r8, mediasCalc['MAPE_Teste'], color="#14CAE5", width=barWidth, label="MAPE Teste")
plt.bar(r9, mediasCalc['MAPE_Treino'], color="#14DEB0", width=barWidth, label="MAPE Treino")

plt.xlabel('Métodos')
plt.xticks([r + barWidth for r in range(len(mediasCalc.index))], metlegreg)
plt.ylabel('Percentual')
plt.title('Avaliação dos Scores')

plt.legend()
plt.show()

# %%
ScoreReg = pd.DataFrame(data=np.reshape(ScoreReg, (9,100)))
ScoreReg = ScoreReg.T
ScoreReg.columns = metlegreg
MAETr = pd.DataFrame(data=np.reshape(MAETr, (9,100)))
MAETr = MAETr.T
MAETr.columns = metlegreg
MAETe = pd.DataFrame(data=np.reshape(MAETe, (9,100)))
MAETe = MAETe.T
MAETe.columns = metlegreg
MSETr = pd.DataFrame(data=np.reshape(MSETr, (9,100)))
MSETr = MSETr.T
MSETr.columns = metlegreg
MSETe = pd.DataFrame(data=np.reshape(MSETe, (9,100)))
MSETe = MSETe.T
MSETe.columns = metlegreg
R2Tr = pd.DataFrame(data=np.reshape(R2Tr, (9,100)))
R2Tr = R2Tr.T
R2Tr.columns = metlegreg
R2Te = pd.DataFrame(data=np.reshape(R2Te, (9,100)))
R2Te = R2Te.T
R2Te.columns = metlegreg
MAPETr = pd.DataFrame(data=np.reshape(MAPETr, (9,100)))
MAPETr = MAPETr.T
MAPETr.columns = metlegreg
MAPETe = pd.DataFrame(data=np.reshape(MAPETe, (9,100)))
MAPETe = MAPETe.T
MAPETe.columns = metlegreg

# %%
MAPETr
# Out:
#          SVR  SVR(BP*)       KNN  KNN(BP*)    ArvReg  ArvReg(BP*)    RanFor  \
# 0   0.106089  0.058624  0.041638  0.015363  0.013978     0.015688  0.023116
# 1   0.100850  0.056120  0.044751  0.015363  0.017203     0.015688  0.025235
# 2   0.103352  0.057439  0.041365  0.015363  0.015134     0.015688  0.024974
# 3   0.101661  0.056677  0.040251  0.015363  0.014843     0.015688  0.023443
# 4   0.100658  0.055621  0.037936  0.015363  0.014433     0.015688  0.022665
# ..       ...       ...       ...       ...       ...          ...       ...
# 95  0.106983  0.060354  0.043197  0.015363  0.018538     0.015688  0.027735
# 96  0.099910  0.057180  0.042681  0.015363  0.016884     0.015688  0.025229
# 97  0.103599  0.057005  0.041331  0.015363  0.014039     0.015688  0.022988
# 98  0.102800  0.057125  0.040218  0.015363  0.011503     0.015688  0.021073
# 99  0.100903  0.057313  0.042864  0.015363  0.014063     0.015688  0.023068
#
#     RanFor(BP*)  ANNR(BP*)
# 0      0.021944   0.069585
# ...

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 6))

bpl = plt.boxplot(MAETe, positions=np.array(range(len(MAETe.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(MAETr, positions=np.array(range(len(MAETr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metlegreg) * 2, 2), metlegreg)
plt.xlim(-2, len(metlegreg)*2)
plt.xlabel("Método")
plt.ylabel("MAE")

plt.savefig('Imagens\Avaliacao\BPMAE.jpeg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-2c6ce6ce6af5> in <module>
#       7 plt.figure(figsize =(12, 6))
#       8
# ----> 9 bpl = plt.boxplot(MAETe, positions=np.array(range(len(MAETe.T)))*2.0-0.4, sym='', widths=0.7)
#      10 bpr = plt.boxplot(MAETr, positions=np.array(range(len(MAETr.T)))*2.0+0.4, sym='', widths=0.7)
#      11 set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
# ...

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 6))

bpl = plt.boxplot(MAPETe, positions=np.array(range(len(MAPETe.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(MAPETr, positions=np.array(range(len(MAPETr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metlegreg) * 2, 2), metlegreg)
plt.xlim(-2, len(metlegreg)*2)
plt.title("MAPE")
plt.xlabel("Método")
plt.ylabel("Percentual")

plt.savefig('Imagens\Avaliacao\BPMAPE.jpeg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ec48fe73c63e> in <module>
#       7 plt.figure(figsize =(12, 6))
#       8
# ----> 9 bpl = plt.boxplot(MAPETe, positions=np.array(range(len(MAPETe.T)))*2.0-0.4, sym='', widths=0.7)
#      10 bpr = plt.boxplot(MAPETr, positions=np.array(range(len(MAPETr.T)))*2.0+0.4, sym='', widths=0.7)
#      11 set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2435         whiskerprops=None, manage_ticks=True, autorange=False,
# ...

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 6))

bpl = plt.boxplot(ScoreReg, positions=np.array(range(len(ScoreReg.T))), sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Score')
plt.legend()

plt.xticks(range(0, len(metlegreg)), metlegreg)
#plt.xlim(metlegreg)
plt.xlabel("Método")
plt.ylabel("Score")

plt.savefig('Imagens\Avaliacao\BPScore.jpeg')

# %%
width=0.9
x = np.array(range(len(ScoreReg.T)))

fig, ax = plt.subplots(figsize=(12,6))

bpl = ax.bar(x, ScoreReg.mean(), width, label="Teste")
plt.legend()

plt.xticks(range(0, len(metlegreg)), metlegreg)
#plt.xlim(-2, len(metlegreg)*2)
plt.title("Precisão")
plt.xlabel("Método")
plt.ylabel("Percentual")

autolabel(bpl)

plt.savefig('Imagens\Avaliacao\Score - Gráfico Barras.jpeg')

# %%
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot()
plt.boxplot(MAETe)

plt.title("BoxPlot Testes")
#plt.xlabel("Teste")
#plt.ylabel("Percentual")
#ax.set_xticklabels(avaliacoes)
plt.show()

# %%
metodosAnn = ['MLPRegressor()', 'MLPRegressor(max_iter=2000)']

db8 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodosAnn[0])))
db9 = pd.read_csv('Relatorio/Regressao/regression_report_{}.csv'.format(str(metodosAnn[1])))

# %%
metlegreg2 = ['ANN', 'ANN(BP*)']

# %%
mediasCalc = []
mediasTest = []
mediasTrain = []
ScoreReg = []
MAETe = []
MAETr = []
MSETe = []
MSETr = []
R2Te = []
R2Tr = []
MAPETe = []
MAPETr = []

# %%
incluirDados(db8)
incluirDados(db9)
calcMedia(db8)
calcMedia(db9)

# %%
mediasCalc = pd.DataFrame(data=np.reshape(mediasCalc, (2,9)), index=metodosAnn, columns=avaliacoes)
mediasCalc
# Out:
#                                 Score   MAE_Teste  MAE_Treino     MSE_Teste  \
# MLPRegressor()              -3.752812  122.262509  121.964172  19263.884332
# MLPRegressor(max_iter=2000)  0.727807   25.474051   26.041723   1078.083832
#
#                                MSE_Treino  R2_Teste  R2_Treino  MAPE_Teste  \
# MLPRegressor()               19160.189483 -3.752812  -3.678754    0.289579
# MLPRegressor(max_iter=2000)   1145.958043  0.727807   0.722083    0.066164
#
#                              MAPE_Treino
# MLPRegressor()                  0.288959
# MLPRegressor(max_iter=2000)     0.069585

# %%
ScoreReg = pd.DataFrame(data=np.reshape(ScoreReg, (2,100)))
ScoreReg = ScoreReg.T
ScoreReg.columns = metlegreg2
MAETr = pd.DataFrame(data=np.reshape(MAETr, (2,100)))
MAETr = MAETr.T
MAETr.columns = metlegreg2
MAETe = pd.DataFrame(data=np.reshape(MAETe, (2,100)))
MAETe = MAETe.T
MAETe.columns = metlegreg2
MSETr = pd.DataFrame(data=np.reshape(MSETr, (2,100)))
MSETr = MSETr.T
MSETr.columns = metlegreg2
MSETe = pd.DataFrame(data=np.reshape(MSETe, (2,100)))
MSETe = MSETe.T
MSETe.columns = metlegreg2
R2Tr = pd.DataFrame(data=np.reshape(R2Tr, (2,100)))
R2Tr = R2Tr.T
R2Tr.columns = metlegreg2
R2Te = pd.DataFrame(data=np.reshape(R2Te, (2,100)))
R2Te = R2Te.T
R2Te.columns = metlegreg2
MAPETr = pd.DataFrame(data=np.reshape(MAPETr, (2,100)))
MAPETr = MAPETr.T
MAPETr.columns = metlegreg2
MAPETe = pd.DataFrame(data=np.reshape(MAPETe, (2,100)))
MAPETe = MAPETe.T
MAPETe.columns = metlegreg2

# %%
def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure(figsize =(12, 6))

bpl = plt.boxplot(MAETe, positions=np.array(range(len(MAETe.T)))*2.0-0.4, sym='', widths=0.7)
bpr = plt.boxplot(MAETr, positions=np.array(range(len(MAETr.T)))*2.0+0.4, sym='', widths=0.7)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Teste')
plt.plot([], c='#2C7BB6', label='Treino')
plt.legend()

plt.xticks(range(0, len(metlegreg2) * 2, 2), metlegreg2)
plt.xlim(-2, len(metlegreg2)*2)
plt.xlabel("Método")
plt.ylabel("MAE")

plt.savefig('Imagens\Avaliacao\BPMAEAnn.jpeg')

# %%
width=0.9
x = np.array(range(len(ScoreReg.T)))

fig, ax = plt.subplots(figsize=(12,6))

bpl = ax.bar(x, ScoreReg.mean(), width, label="Teste")
plt.legend()

plt.xticks(range(0, len(metlegreg2)), metlegreg2)
#plt.xlim(-2, len(metlegreg)*2)
plt.title("Precisão")
plt.xlabel("Método")
plt.ylabel("Percentual")

autolabel(bpl)

plt.savefig('Imagens\Avaliacao\ScoreANN - Gráfico Barras.jpeg')
